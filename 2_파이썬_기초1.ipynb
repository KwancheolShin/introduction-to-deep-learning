# %% [markdown]
# <a href="https://colab.research.google.com/github/KwancheolShin/introduction-to-deep-learning/blob/main/2_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%881.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파이썬 버전확인하기

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# #1. 자료형
# 프로그래밍 언어에는 자료형data type이라는 것이 있다. 자료형이란 데이터의 성질을 나타내는 것으로, 예를 들어 정수, 실수, 문자열과 같은 형태가 있다. type() 함수로 특정 데이터의 자료형을 알아볼 수 있다.

# %%
type(10)
# Out:
# int

# %%
print(type(10)) #10은 int라는 클래스(자료형)다.
# Out:
# <class 'int'>

# %%
type(2.718)
# Out:
# float

# %%
type("Hello")
# Out:
# str

# %% [markdown]
# #2. 변수

# %%
x=10
print(x)
# Out:
# 10

# %%
x=100
print(x)
# Out:
# 100

# %%
y = 3.14
x*y
# Out:
# 314.0

# %%
type(x*y)
# Out:
# float

# %% [markdown]
# 파이썬은 **동적 언어**로 분류되는 프로그래밍 언어이다. 동적이라 함은 변수의 자료형을 상황에 맞게 자동으로 결정한다는 뜻이다.

# %% [markdown]
# #3. 자료구조
# 파이썬에서 사용하는 대표적인 자료구조는 리스트list, 튜플tuple, 딕셔너리dictionaly, 셋set이 있다.
# ##3.1리스트
# 여러 데이터를 리스트list로 정리할 수 있다.

# %%
a = [1,2,'three','four',5]
print(a)
# Out:
# [1, 2, 'three', 'four', 5]

# %%
print(a[0]) #리스트는 인덱스index로 접근할 수 있다. 인덱스는 앞에서는 0부터, 뒤에서는 -1부터 시작한다.
# Out:
# 10

# %%
print(a[-1])
# Out:
# 5

# %%
print(a[0],a[1],a[2])
# Out:
# 1 2 three

# %%
print(a[0:2]) #슬라이싱을 이용하면 범위를 지정해 부분 리스트를 얻을 수 있다.
# Out:
# [10, 2]

# %%
print(a[:3]) #처음부터 세번째까지
# Out:
# [10, 2, 'three']

# %%
print(a[:-2])
# Out:
# [10, 2, 'three']

# %%
len(a) #길이
# Out:
# 5

# %%
a[0] = 10 #리스트의 값을 바꿀수 있다.
print(a)
# Out:
# [10, 2, 'three', 'four', 5]

# %% [markdown]
# ##3.2 딕셔너리
# 리스트는 인덱스 번호로 0,1,2, ... 순으로 값을 지정하는 반면, 딕셔너리dictionary는 키key와 값value을 한 쌍으로 저장한다. 즉, 영한사전처럼 단어와 그 의미를 짝지어 저장한다. 중괄호{}로 정의하며 키와 값은 콜론:으로 연결한다.
# 키를 이용하여 접근해서 값을 호출하고 변경하고 추가하고 삭제할 수 있다.

# %%
me = {"이름":"신관철", "키":195, "몸무게":90, "나이":20, "학교":"이화여자대학교"}
print(me)
# Out:
# {'이름': '신관철', '키': 195, '몸무게': 90, '나이': 20, '학교': '이화여자대학교'}

# %%
me["키"]
# Out:
# 195

# %%
me["키"] = 185

# %%
print(me)
# Out:
# {'이름': '신관철', '키': 185, '몸무게': 90, '나이': 20, '학교': '이화여자대학교'}

# %%
me["주소"] = "서울" # 딕셔너리 값 추가
print(me)
# Out:
# {'이름': '신관철', '키': 185, '몸무게': 90, '나이': 20, '학교': '이화여자대학교', '주소': '서울'}

# %%
del me["주소"] #디셔러니 값 삭제
print(me)
# Out:
# {'이름': '신관철', '키': 185, '몸무게': 90, '나이': 20, '학교': '이화여자대학교'}

# %%
for key,value in me.items(): #반복문으로 출력하기
  print(key,value)
# Out:
# 이름 신관철
# 키 185
# 몸무게 90
# 나이 20
# 학교 이화여자대학교

# %% [markdown]
# ##3.3 bool
# bool 자료형은 True와 False라는 두 값 중 하나를 취한다.
# bool에는 and, or, not 연산자를 사용할 수 있다.

# %%
hungry = True
sleepy = False

# %%
type(hungry)
# Out:
# bool

# %%
print(hungry)
# Out:
# True

# %%
print(int(hungry))
# Out:
# 1

# %%
print(int(sleepy))
# Out:
# 0

# %% [markdown]
# #4. 논리연산자(and,or,not)

# %%
print(hungry and hungry)
print(hungry and sleepy)
print(sleepy and hungry)
print(sleepy and sleepy)
# Out:
# True
# False
# False
# False

# %%
print(hungry or hungry)
print(hungry or sleepy)
print(sleepy or hungry)
print(sleepy or sleepy)
# Out:
# True
# True
# True
# False

# %%
print(not hungry)
print(not False)
# Out:
# False
# True

# %% [markdown]
# ##5. 조건문
# 조건에 따라 달리 처리하려면 if/else 문을 사용한다.

# %%
hungry = True

if hungry:
  print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False
if hungry:
  print("I'm hungry.")
else:
  print("I'm not hungry.")
  print("I'm sleepy.")
# Out:
# I'm not hungry.
# I'm sleepy.
